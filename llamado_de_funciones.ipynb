# %%
import pandas as pd
import funciones as fn

# %%
# Cargar el archivo CSV
# Agregar y cargar archivo del país
df = pd.read_csv('Sicily.csv')

# %%
# Sustituir valores nulos
# Reemplazamos valores nulos del dataframe con "mean"
data1 = df.fillna(method = 'ffill')
data1
# Out:
# /var/folders/lk/1s80q3g16rl6xn6yqybdsx3m0000gn/T/ipykernel_6929/1582366507.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 = df.fillna(method = 'ffill')
#        Unnamed: 0                                               name  \
# 0               0               SEASIDE - Historic Antique Residence
# 1               1  BnB center near station with balcony and break...
# 2               2                         Etna-sea a panoramic villa
# 3               3                             Two steps from the sea
# 4               4                                    Villa Verdemare
# ...           ...                                                ...
# 57958       57958                       Appartamento Salgari Levante
# 57959       57959                       Appartamento Salgari Ponente
# 57960       57960                         Mini appartamento in Villa
# ...

# %%
# Identificar valores nulos
nulos_info = identificar_nulos(df)
print("Valores nulos por columna:\n", nulos_info["nulos_por_columna"])
print("Total de valores nulos en el DataFrame:", nulos_info["nulos_totales"])
